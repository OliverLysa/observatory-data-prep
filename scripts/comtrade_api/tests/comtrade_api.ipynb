# %%
# Define functions 

# Define save CSV
def save_csv(data, filename):
    """
    :param csv_inputs:
    :return:
    """
    try:
        with open(filename, "w", encoding='utf-8', newline='') as f:
            writer = csv.writer(f)
            writer.writerows(data)
    except Exception as e:
        print(str(e))
        print("File {} not found or format is wrong".format(filename))

# %%
# Install a pip comtradeapicall package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install --upgrade comtradeapicall
# Out:
# Requirement already satisfied: comtradeapicall in /Users/oliverlysaght/anaconda3/lib/python3.10/site-packages (1.0.20)

# %%
# Install a pip pandas package in the current Jupyter kernel
import sys
# !{sys.executable} -m pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/oliverlysaght/anaconda3/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/oliverlysaght/anaconda3/lib/python3.10/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/oliverlysaght/anaconda3/lib/python3.10/site-packages (from pandas) (2022.7)
# Requirement already satisfied: numpy>=1.21.0 in /Users/oliverlysaght/anaconda3/lib/python3.10/site-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /Users/oliverlysaght/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
# Import libraries
import pandas
import requests
import comtradeapicall

# %%
# Set variables
from datetime import date
from datetime import timedelta
today = date.today()
yesterday = today - timedelta(days=1)
lastweek = today - timedelta(days=7)

# %%
# Set subscription key and directory
subscription_key = 'c5fed294c36c4a38b61f6da8eaf24fc2' # comtrade api subscription key (from comtradedeveloper.un.org)
directory = '<OUTPUT DIR>'  # output directory for downloaded files

# %%
# Call get data API to a data frame, max to 250K records, subscription key required

# %%
mydf = comtradeapicall.getFinalData(subscription_key,
                                    # Type of trade: C for commodities and S for service
                                    typeCode='C',
                                    # Trade frequency: A for annual and M for monthly
                                    freqCode='A',
                                    # Trade (IMTS) classifications: HS, SITC, BEC or EBOPS.
                                    clCode='HS', 
                                    # Year or month. Year should be 4 digit year. Month should be six digit integer with the values of the form YYYYMM
                                    period='1995',
                                    # Reporter code (Possible values are M49 code of the countries separated by comma (,))
                                    reporterCode='826',
                                    # Commodity code. Multi value input should be in the form of csv (Codes separated by comma (,))
                                    cmdCode='26',
                                    # Trade flow code. Multi value input should be in the form of csv (Codes separated by comma (,))
                                    flowCode='M',
                                    # Partner code (Possible values are M49 code of the countries separated by comma (,))
                                    partnerCode=None,
                                    partner2Code=None,
                                    # Customs code. Multi value input should be in the form of csv (Codes separated by comma (,))
                                    customsCode=None, 
                                    motCode=None,
                                    # Output format
                                    format_output='JSON',
                                    # Add parameters in csv list on which you want the results to be aggregated
                                    aggregateBy=None,
                                    # Mode to choose from
                                    breakdownMode='classic',
                                    countOnly=None,
                                    # Include description
                                    includeDesc=True)

# %%
# Look at head of data
mydf.head(5)
# Out:
#   typeCode freqCode  refPeriodId  refYear  refMonth period  reporterCode  \
# 0        C        A     19950101     1995        52   1995           826
# 1        C        A     19950101     1995        52   1995           826
# 2        C        A     19950101     1995        52   1995           826
# 3        C        A     19950101     1995        52   1995           826
# 4        C        A     19950101     1995        52   1995           826
#
#   reporterISO    reporterDesc flowCode  ... netWgt  isNetWgtEstimated  \
# 0         GBR  United Kingdom        M  ...   None              False
# 1         GBR  United Kingdom        M  ...   None              False
# 2         GBR  United Kingdom        M  ...   None              False
# 3         GBR  United Kingdom        M  ...   None              False
# 4         GBR  United Kingdom        M  ...   None              False
#
#   grossWgt isGrossWgtEstimated      cifvalue fobvalue  primaryValue  \
# 0     None               False  1.313138e+09     None  1.313138e+09
# 1     None               False  1.645328e+06     None  1.645328e+06
# 2     None               False  2.560453e+08     None  2.560453e+08
# 3     None               False  3.037612e+06     None  3.037612e+06
# 4     None               False  3.459747e+07     None  3.459747e+07
#
#   legacyEstimationFlag isReported  isAggregate
# 0                    0       True        False
# 1                    0       True        False
# 2                    0       True        False
# 3                    0       True        False
# 4                    0       True        False
#
# [5 rows x 47 columns]

# %%
# Save results to CSV file
mydf.to_csv('comtrade_api.csv')
